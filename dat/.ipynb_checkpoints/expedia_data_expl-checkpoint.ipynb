# %% [markdown]
# data from here: https://www.kaggle.com/c/expedia-hotel-recommendations/data

# %%
import numpy as np
import pandas as pd

# %%
# !wc -l train.csv
# Out:
# 37670294 train.csv

# %%
# !head train.csv -n 2500000 > train_small.csv

# %%
test_dat = pd.read_csv('test.csv')
test_dat.head()
# Out:
#    id            date_time  site_name  posa_continent  user_location_country  \
# 0   0  2015-09-03 17:09:54          2               3                     66
# 1   1  2015-09-24 17:38:35          2               3                     66
# 2   2  2015-06-07 15:53:02          2               3                     66
# 3   3  2015-09-14 14:49:10          2               3                     66
# 4   4  2015-07-17 09:32:04          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   174               37449                  5539.0567
# 1                   174               37449                  5873.2923
# 2                   142               17440                  3975.9776
# 3                   258               34156                  1508.5975
# 4                   467               36345                    66.7913
#
# ...

# %%
test_dat.shape
# Out:
# (2528243, 22)

# %%
train_dat = pd.read_csv('train_small.csv')
train_dat.head()
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-08-11 07:46:59          2               3                     66
# 1  2014-08-11 08:22:12          2               3                     66
# 2  2014-08-11 08:24:33          2               3                     66
# 3  2014-08-09 18:05:16          2               3                     66
# 4  2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package      ...        srch_children_cnt  \
# ...

# %%
train_dat.shape
# Out:
# (2499999, 24)

# %%
test_dat.columns
# Out:
# Index(['id', 'date_time', 'site_name', 'posa_continent',
#        'user_location_country', 'user_location_region', 'user_location_city',
#        'orig_destination_distance', 'user_id', 'is_mobile', 'is_package',
#        'channel', 'srch_ci', 'srch_co', 'srch_adults_cnt', 'srch_children_cnt',
#        'srch_rm_cnt', 'srch_destination_id', 'srch_destination_type_id',
#        'hotel_continent', 'hotel_country', 'hotel_market'],
#       dtype='object')

# %%
train_dat.columns
# Out:
# Index(['date_time', 'site_name', 'posa_continent', 'user_location_country',
#        'user_location_region', 'user_location_city',
#        'orig_destination_distance', 'user_id', 'is_mobile', 'is_package',
#        'channel', 'srch_ci', 'srch_co', 'srch_adults_cnt', 'srch_children_cnt',
#        'srch_rm_cnt', 'srch_destination_id', 'srch_destination_type_id',
#        'is_booking', 'cnt', 'hotel_continent', 'hotel_country', 'hotel_market',
#        'hotel_cluster'],
#       dtype='object')

# %%
temp = list(test_dat.columns)
temp2 = list(train_dat.columns)
temp.extend(temp2)

temp = np.array(temp)
temp = np.unique(temp)

# %%
for i in temp:
    if i not in list(train_dat.columns):
        print(i, '- isnt in train dat')
# Out:
# id - isnt in train dat

# %%
for i in temp:
    if i not in list(test_dat.columns):
        print(i, '- isnt in test dat')
# Out:
# cnt - isnt in test dat
# hotel_cluster - isnt in test dat
# is_booking - isnt in test dat

# %%
train_dat.describe()
# Out:
#          site_name  posa_continent  user_location_country  \
# count  9999.000000     9999.000000            9999.000000
# mean      8.262026        2.744374              85.713671
# std      10.352332        0.590535              61.548663
# min       2.000000        0.000000               0.000000
# 25%       2.000000        3.000000              66.000000
# 50%       2.000000        3.000000              66.000000
# 75%      11.000000        3.000000              69.000000
# max      47.000000        4.000000             239.000000
#
#        user_location_region  user_location_city  orig_destination_distance  \
# count           9999.000000         9999.000000                6270.000000
# mean             272.580158        26943.817682                1833.817586
# std              178.460410        17471.507133                2028.427271
# min                0.000000            3.000000                   0.065100
# ...

# %%
test_dat.describe()
# Out:
#                  id     site_name  posa_continent  user_location_country  \
# count  2.528243e+06  2.528243e+06    2.528243e+06           2.528243e+06
# mean   1.264121e+06  9.709666e+00    2.697413e+00           8.551612e+01
# std    7.298410e+05  1.227183e+01    7.651288e-01           5.673880e+01
# min    0.000000e+00  0.000000e+00    0.000000e+00           0.000000e+00
# 25%    6.320605e+05  2.000000e+00    3.000000e+00           6.600000e+01
# 50%    1.264121e+06  2.000000e+00    3.000000e+00           6.600000e+01
# 75%    1.896182e+06  1.300000e+01    3.000000e+00           6.900000e+01
# max    2.528242e+06  5.300000e+01    4.000000e+00           2.390000e+02
#
#        user_location_region  user_location_city  orig_destination_distance  \
# count          2.528243e+06        2.528243e+06               1.680782e+06
# mean           3.170341e+02        2.786218e+04               1.686398e+03
# std            2.082834e+02        1.668788e+04               2.197361e+03
# ...

# %%
train_dat['user_id'].unique().shape[0]/train_dat.shape[0]
# Out:
# 0.032342812937125175

# %%
test_dat['user_id'].unique().shape[0]/test_dat.shape[0]
# Out:
# 0.4673510418104589
